# %%
import pandas as pd
from tqdm.auto import tqdm
from htvs_module.htvs_mods import get_indirect_structure

# %%
formula_and_structure_df = pd.read_csv('./data/05_2_sub_structure_with_predictions.csv')
formula_and_structure_df
# Out:
#                             sub_comp        mpid reduced_formula  index  \
# 0   ['Li', 'S', 'Ge', 1.0, 1.0, 2.0]  mp-1001784          LiGe2S     16
# 1   ['Li', 'S', 'Ge', 1.0, 1.0, 2.0]  mp-1025496          LiGe2S    240
# 2   ['Li', 'S', 'Ge', 1.0, 1.0, 2.0]  mp-1029395          LiGe2S    352
# 3   ['Li', 'S', 'As', 1.0, 1.0, 2.0]  mp-1001784          LiAs2S     17
# 4   ['Li', 'S', 'As', 1.0, 1.0, 2.0]  mp-1025496          LiAs2S    241
# 5   ['Li', 'S', 'As', 1.0, 1.0, 2.0]  mp-1029395          LiAs2S    353
# 6    ['Li', 'B', 'S', 1.0, 1.0, 2.0]  mp-1001784           LiBS2     29
# 7    ['Li', 'B', 'S', 1.0, 1.0, 2.0]  mp-1025496           LiBS2    253
# 8    ['Li', 'B', 'S', 1.0, 1.0, 2.0]  mp-1029395           LiBS2    365
# 9   ['Li', 'Al', 'S', 1.0, 1.0, 2.0]  mp-1001784          LiAlS2     36
# 10  ['Li', 'Al', 'S', 1.0, 1.0, 2.0]  mp-1025496          LiAlS2    260
# 11  ['Li', 'Al', 'S', 1.0, 1.0, 2.0]  mp-1029395          LiAlS2    372
# ...

# %% [markdown]
# # Get structrue representations and delete duplications

# %%
formula_and_structure_df = get_indirect_structure(formula_and_structure_df)
formula_and_structure_df
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]
#                             sub_comp        mpid reduced_formula  index  \
# 0   ['Li', 'S', 'Ge', 1.0, 1.0, 2.0]  mp-1001784          LiGe2S     16
# 1   ['Li', 'S', 'Ge', 1.0, 1.0, 2.0]  mp-1025496          LiGe2S    240
# 2   ['Li', 'S', 'Ge', 1.0, 1.0, 2.0]  mp-1029395          LiGe2S    352
# 3   ['Li', 'S', 'As', 1.0, 1.0, 2.0]  mp-1001784          LiAs2S     17
# 4   ['Li', 'S', 'As', 1.0, 1.0, 2.0]  mp-1025496          LiAs2S    241
# 5   ['Li', 'S', 'As', 1.0, 1.0, 2.0]  mp-1029395          LiAs2S    353
# 6    ['Li', 'B', 'S', 1.0, 1.0, 2.0]  mp-1001784           LiBS2     29
# 7    ['Li', 'B', 'S', 1.0, 1.0, 2.0]  mp-1025496           LiBS2    253
# 8    ['Li', 'B', 'S', 1.0, 1.0, 2.0]  mp-1029395           LiBS2    365
# 9   ['Li', 'Al', 'S', 1.0, 1.0, 2.0]  mp-1001784          LiAlS2     36
# 10  ['Li', 'Al', 'S', 1.0, 1.0, 2.0]  mp-1025496          LiAlS2    260
# ...

# %%
formula_and_structure_df.to_csv('./data/06_1_after_bulk_enumerator.csv',index=False)
formula_and_structure_df=pd.read_csv('./data/06_1_after_bulk_enumerator.csv')

# %%
drop_dupl_df = formula_and_structure_df.drop_duplicates(['reduced_formula','spacegroup','wyckoffs','species'],keep='first')
drop_dupl_df
# Out:
#                             sub_comp        mpid reduced_formula  index  \
# 0   ['Li', 'S', 'Ge', 1.0, 1.0, 2.0]  mp-1001784          LiGe2S     16
# 1   ['Li', 'S', 'Ge', 1.0, 1.0, 2.0]  mp-1025496          LiGe2S    240
# 2   ['Li', 'S', 'Ge', 1.0, 1.0, 2.0]  mp-1029395          LiGe2S    352
# 3   ['Li', 'S', 'As', 1.0, 1.0, 2.0]  mp-1001784          LiAs2S     17
# 4   ['Li', 'S', 'As', 1.0, 1.0, 2.0]  mp-1025496          LiAs2S    241
# 5   ['Li', 'S', 'As', 1.0, 1.0, 2.0]  mp-1029395          LiAs2S    353
# 6    ['Li', 'B', 'S', 1.0, 1.0, 2.0]  mp-1001784           LiBS2     29
# 7    ['Li', 'B', 'S', 1.0, 1.0, 2.0]  mp-1025496           LiBS2    253
# 8    ['Li', 'B', 'S', 1.0, 1.0, 2.0]  mp-1029395           LiBS2    365
# 9   ['Li', 'Al', 'S', 1.0, 1.0, 2.0]  mp-1001784          LiAlS2     36
# 10  ['Li', 'Al', 'S', 1.0, 1.0, 2.0]  mp-1025496          LiAlS2    260
# 11  ['Li', 'Al', 'S', 1.0, 1.0, 2.0]  mp-1029395          LiAlS2    372
# ...

# %%
drop_dupl_df.to_csv('./data/06_2_drop_duplicate.csv',index=False)
